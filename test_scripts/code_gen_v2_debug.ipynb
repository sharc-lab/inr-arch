# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

import os
import shutil
from pathlib import Path
import pickle
from typing import Optional
import subprocess


from rich import print
from rich.pretty import pprint as pp

# %%
from src.code_gen import code_gen_v2
from src.plotting import plot_graph, plot_grad_graph
from src.profiling import profileit
from src.inr_dsp import Project, FPX

# %%
model_fp = Path("./src/test_files/new_grad_lastdim_small.pkl")

with open(model_fp, "rb") as f:
    G_data = pickle.load(f)

print(G_data)
# Out:
# DiGraph with 108 nodes and 131 edges

# %%
cpp = code_gen_v2.gen_model_cpp("test", G_data)
print(cpp)
# Out:
# #include "model.h"
#
# F_TYPE input_net_0_0_bias[256];
# F_TYPE input_net_0_0_weight[256][2];
# F_TYPE input_net_1_0_bias[256];
# F_TYPE input_net_1_0_weight[256][256];
# F_TYPE input_net_2_0_bias[256];
# F_TYPE input_net_2_0_weight[256][256];
# F_TYPE input_net_3_0_bias[256];
# F_TYPE input_net_3_0_weight[256][256];
# F_TYPE input_net_4_0_bias[3];
# F_TYPE input_net_4_0_weight[3][256];
# F_TYPE input_x[4096][2];
#
# array_stream<F_TYPE, array_shape<256>, 1> input_net_0_0_bias_stream;
# array_stream<F_TYPE, array_shape<256, 2>, 1> input_net_0_0_weight_stream;
# array_stream<F_TYPE, array_shape<256>, 1> input_net_1_0_bias_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> input_net_1_0_weight_stream;
# array_stream<F_TYPE, array_shape<256>, 1> input_net_2_0_bias_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> input_net_2_0_weight_stream;
# array_stream<F_TYPE, array_shape<256>, 1> input_net_3_0_bias_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> input_net_3_0_weight_stream;
# array_stream<F_TYPE, array_shape<3>, 1> input_net_4_0_bias_stream;
# array_stream<F_TYPE, array_shape<3, 256>, 1> input_net_4_0_weight_stream;
# array_stream<F_TYPE, array_shape<4096, 2>, 1> input_x_stream;
#
# F_TYPE output_0[4096];
# F_TYPE output_1[4096];
# F_TYPE output_2[4096];
# F_TYPE output_3[4096];
# F_TYPE output_4[4096];
# F_TYPE output_5[4096];
# F_TYPE output_6[4096];
# F_TYPE output_7[4096];
# F_TYPE output_8[4096];
#
# array_stream<F_TYPE, array_shape<4096>, 1> output_0_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> output_1_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> output_2_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> output_3_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> output_4_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> output_5_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> output_6_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> output_7_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> output_8_stream;
#
# array_stream<F_TYPE, array_shape<1, 256>, 1> fn_Unsqueeze_0__out_stream;
# array_stream<F_TYPE, array_shape<2, 256>, 1> fn_T_15__out_stream;
# array_stream<F_TYPE, array_shape<1, 256>, 1> fn_Unsqueeze_1__out_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_T_16__out_stream;
# array_stream<F_TYPE, array_shape<1, 256>, 1> fn_Unsqueeze_2__out_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_T_17__out_stream;
# array_stream<F_TYPE, array_shape<1, 256>, 1> fn_Unsqueeze_3__out_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_T_18__out_stream;
# array_stream<F_TYPE, array_shape<1, 3>, 1> fn_Unsqueeze_4__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_14__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_19__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_9__out_stream;
# array_stream<F_TYPE, array_shape<256, 3>, 1> fn_T_19__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_4__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Add_4__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_3__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_11__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_3__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_7__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Sin_3__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_3__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Add_3__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_2__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_10__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_2__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_6__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Sin_2__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_2__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Add_2__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_1__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_1__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_5__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_9__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Sin_1__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_1__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Add_1__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_0__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_0__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_4__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_8__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_11__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_10__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_8__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_19__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_18__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_13__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_17__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_16__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_12__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_15__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_14__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_11__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_13__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_12__out_stream;
# array_stream<F_TYPE, array_shape<4096, 2>, 1> fn_Mm_10__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_27__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_26__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_18__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_25__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_24__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_17__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_23__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_22__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_16__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_21__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_20__out_stream;
# array_stream<F_TYPE, array_shape<4096, 2>, 1> fn_Mm_15__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_9__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_8__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_7__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_7__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_6__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_6__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_5__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_4__out_stream;
# array_stream<F_TYPE, array_shape<4096, 2>, 1> fn_Mm_5__out_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> fn_Select_3__out_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> fn_Select_4__out_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> fn_Select_5__out_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> fn_Select_6__out_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> fn_Select_7__out_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> fn_Select_8__out_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Sin_0__out_stream;
# array_stream<F_TYPE, array_shape<4096, 3>, 1> fn_Mm_0__out_stream;
# array_stream<F_TYPE, array_shape<4096, 3>, 1> fn_Add_0__out_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> fn_Select_0__out_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> fn_Select_1__out_stream;
# array_stream<F_TYPE, array_shape<4096>, 1> fn_Select_2__out_stream;
#
# array_stream<F_TYPE, array_shape<4096, 3>, 1> fn_Select_0__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 3>, 1> fn_Select_1__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 3>, 1> fn_Select_2__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 3>, 1> fn_Add_0__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_0__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Sin_0__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_0__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_4__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_8__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_0__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Add_1__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_1__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Sin_1__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_1__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_5__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_9__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_1__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Add_2__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_2__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Sin_2__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_2__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_6__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_10__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_2__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Add_3__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_3__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Sin_3__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_3__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_7__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Cos_11__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_3__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Add_4__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 2>, 1> fn_Mm_4__in_0_stream;
# array_stream<F_TYPE, array_shape<256, 2>, 1> fn_T_15__in_0_stream;
# array_stream<F_TYPE, array_shape<256, 2>, 1> fn_Mm_5__in_1_stream;
# array_stream<F_TYPE, array_shape<256, 2>, 1> fn_Mm_10__in_1_stream;
# array_stream<F_TYPE, array_shape<256, 2>, 1> fn_Mm_15__in_1_stream;
# array_stream<F_TYPE, array_shape<1, 256>, 1> fn_Add_4__in_1_stream;
# array_stream<F_TYPE, array_shape<256>, 1> fn_Unsqueeze_0__in_0_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_T_16__in_0_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_Mm_6__in_1_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_Mm_11__in_1_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_Mm_16__in_1_stream;
# array_stream<F_TYPE, array_shape<1, 256>, 1> fn_Add_3__in_1_stream;
# array_stream<F_TYPE, array_shape<256>, 1> fn_Unsqueeze_1__in_0_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_T_17__in_0_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_Mm_7__in_1_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_Mm_12__in_1_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_Mm_17__in_1_stream;
# array_stream<F_TYPE, array_shape<1, 256>, 1> fn_Add_2__in_1_stream;
# array_stream<F_TYPE, array_shape<256>, 1> fn_Unsqueeze_2__in_0_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_T_18__in_0_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_Mm_8__in_1_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_Mm_13__in_1_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_Mm_18__in_1_stream;
# array_stream<F_TYPE, array_shape<1, 256>, 1> fn_Add_1__in_1_stream;
# array_stream<F_TYPE, array_shape<256>, 1> fn_Unsqueeze_3__in_0_stream;
# array_stream<F_TYPE, array_shape<3, 256>, 1> fn_T_19__in_0_stream;
# array_stream<F_TYPE, array_shape<3, 256>, 1> fn_Mm_9__in_1_stream;
# array_stream<F_TYPE, array_shape<3, 256>, 1> fn_Mm_14__in_1_stream;
# array_stream<F_TYPE, array_shape<3, 256>, 1> fn_Mm_19__in_1_stream;
# array_stream<F_TYPE, array_shape<1, 3>, 1> fn_Add_0__in_1_stream;
# array_stream<F_TYPE, array_shape<3>, 1> fn_Unsqueeze_4__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 2>, 1> fn_Select_3__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 2>, 1> fn_Select_4__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_5__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_4__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_5__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_6__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_6__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_7__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_7__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_8__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_9__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_8__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_10__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_11__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_11__in_1_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_9__in_1_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_7__in_1_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_5__in_1_stream;
# array_stream<F_TYPE, array_shape<4096, 2>, 1> fn_Select_5__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 2>, 1> fn_Select_6__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_10__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_12__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_13__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_11__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_14__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_15__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_12__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_16__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_17__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_13__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_18__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_19__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_19__in_1_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_17__in_1_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_15__in_1_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_13__in_1_stream;
# array_stream<F_TYPE, array_shape<4096, 2>, 1> fn_Select_7__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 2>, 1> fn_Select_8__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_15__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_20__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_21__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_16__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_22__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_23__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_17__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_24__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_25__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mm_18__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_26__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_27__in_0_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_27__in_1_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_25__in_1_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_23__in_1_stream;
# array_stream<F_TYPE, array_shape<4096, 256>, 1> fn_Mul_21__in_1_stream;
# array_stream<F_TYPE, array_shape<2, 256>, 1> fn_Mm_4__in_1_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_Mm_3__in_1_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_Mm_2__in_1_stream;
# array_stream<F_TYPE, array_shape<256, 256>, 1> fn_Mm_1__in_1_stream;
# array_stream<F_TYPE, array_shape<256, 3>, 1> fn_Mm_0__in_1_stream;
#
# void main_dataflow_region(){
#
# #pragma HLS DATAFLOW
#
# array_1d_to_array_stream<F_TYPE, 256>(input_net_0_0_bias, input_net_0_0_bias_stream);
# array_2d_to_array_stream<F_TYPE, 256, 2>(input_net_0_0_weight, input_net_0_0_weight_stream);
# array_1d_to_array_stream<F_TYPE, 256>(input_net_1_0_bias, input_net_1_0_bias_stream);
# array_2d_to_array_stream<F_TYPE, 256, 256>(input_net_1_0_weight, input_net_1_0_weight_stream);
# array_1d_to_array_stream<F_TYPE, 256>(input_net_2_0_bias, input_net_2_0_bias_stream);
# array_2d_to_array_stream<F_TYPE, 256, 256>(input_net_2_0_weight, input_net_2_0_weight_stream);
# array_1d_to_array_stream<F_TYPE, 256>(input_net_3_0_bias, input_net_3_0_bias_stream);
# array_2d_to_array_stream<F_TYPE, 256, 256>(input_net_3_0_weight, input_net_3_0_weight_stream);
# array_1d_to_array_stream<F_TYPE, 3>(input_net_4_0_bias, input_net_4_0_bias_stream);
# array_2d_to_array_stream<F_TYPE, 3, 256>(input_net_4_0_weight, input_net_4_0_weight_stream);
# array_2d_to_array_stream<F_TYPE, 4096, 2>(input_x, input_x_stream);
#
#
# // fn_Unsqueeze_0
# unsqueeze(fn_Unsqueeze_0__in_0_stream, fn_Unsqueeze_0__out_stream, 0);
#
# const decltype(fn_Unsqueeze_0__out_stream) fn_Unsqueeze_0__destinations[1] = { fn_Add_4__in_1_stream };
# copy_stream<1>(fn_Unsqueeze_0__out_stream, fn_Unsqueeze_0__destinations);
#
# ////////////////
#
#
# // fn_T_15
# transpose_2d(fn_T_15__in_0_stream, fn_T_15__out_stream);
#
# const decltype(fn_T_15__out_stream) fn_T_15__destinations[1] = { fn_Mm_4__in_1_stream };
# copy_stream<1>(fn_T_15__out_stream, fn_T_15__destinations);
#
# ////////////////
#
#
# // fn_Unsqueeze_1
# unsqueeze(fn_Unsqueeze_1__in_0_stream, fn_Unsqueeze_1__out_stream, 0);
#
# const decltype(fn_Unsqueeze_1__out_stream) fn_Unsqueeze_1__destinations[1] = { fn_Add_3__in_1_stream };
# copy_stream<1>(fn_Unsqueeze_1__out_stream, fn_Unsqueeze_1__destinations);
#
# ////////////////
#
#
# // fn_T_16
# transpose_2d(fn_T_16__in_0_stream, fn_T_16__out_stream);
#
# const decltype(fn_T_16__out_stream) fn_T_16__destinations[1] = { fn_Mm_3__in_1_stream };
# copy_stream<1>(fn_T_16__out_stream, fn_T_16__destinations);
#
# ////////////////
#
#
# // fn_Unsqueeze_2
# unsqueeze(fn_Unsqueeze_2__in_0_stream, fn_Unsqueeze_2__out_stream, 0);
#
# const decltype(fn_Unsqueeze_2__out_stream) fn_Unsqueeze_2__destinations[1] = { fn_Add_2__in_1_stream };
# copy_stream<1>(fn_Unsqueeze_2__out_stream, fn_Unsqueeze_2__destinations);
#
# ////////////////
#
#
# // fn_T_17
# transpose_2d(fn_T_17__in_0_stream, fn_T_17__out_stream);
#
# const decltype(fn_T_17__out_stream) fn_T_17__destinations[1] = { fn_Mm_2__in_1_stream };
# copy_stream<1>(fn_T_17__out_stream, fn_T_17__destinations);
#
# ////////////////
#
#
# // fn_Unsqueeze_3
# unsqueeze(fn_Unsqueeze_3__in_0_stream, fn_Unsqueeze_3__out_stream, 0);
#
# const decltype(fn_Unsqueeze_3__out_stream) fn_Unsqueeze_3__destinations[1] = { fn_Add_1__in_1_stream };
# copy_stream<1>(fn_Unsqueeze_3__out_stream, fn_Unsqueeze_3__destinations);
#
# ////////////////
#
#
# // fn_T_18
# transpose_2d(fn_T_18__in_0_stream, fn_T_18__out_stream);
#
# const decltype(fn_T_18__out_stream) fn_T_18__destinations[1] = { fn_Mm_1__in_1_stream };
# copy_stream<1>(fn_T_18__out_stream, fn_T_18__destinations);
#
# ////////////////
#
#
# // fn_Unsqueeze_4
# unsqueeze(fn_Unsqueeze_4__in_0_stream, fn_Unsqueeze_4__out_stream, 0);
#
# const decltype(fn_Unsqueeze_4__out_stream) fn_Unsqueeze_4__destinations[1] = { fn_Add_0__in_1_stream };
# copy_stream<1>(fn_Unsqueeze_4__out_stream, fn_Unsqueeze_4__destinations);
#
# ////////////////
#
#
# // fn_Mm_14
# mm(fn_Mm_14__in_0_stream, fn_Mm_14__in_1_stream, fn_Mm_14__out_stream);
#
# const decltype(fn_Mm_14__out_stream) fn_Mm_14__destinations[1] = { fn_Mul_19__in_1_stream };
# copy_stream<1>(fn_Mm_14__out_stream, fn_Mm_14__destinations);
#
# ////////////////
#
#
# // fn_Mm_19
# mm(fn_Mm_19__in_0_stream, fn_Mm_19__in_1_stream, fn_Mm_19__out_stream);
#
# const decltype(fn_Mm_19__out_stream) fn_Mm_19__destinations[1] = { fn_Mul_27__in_1_stream };
# copy_stream<1>(fn_Mm_19__out_stream, fn_Mm_19__destinations);
#
# ////////////////
#
#
# // fn_Mm_9
# mm(fn_Mm_9__in_0_stream, fn_Mm_9__in_1_stream, fn_Mm_9__out_stream);
#
# const decltype(fn_Mm_9__out_stream) fn_Mm_9__destinations[1] = { fn_Mul_11__in_1_stream };
# copy_stream<1>(fn_Mm_9__out_stream, fn_Mm_9__destinations);
#
# ////////////////
#
#
# // fn_T_19
# transpose_2d(fn_T_19__in_0_stream, fn_T_19__out_stream);
#
# const decltype(fn_T_19__out_stream) fn_T_19__destinations[1] = { fn_Mm_0__in_1_stream };
# copy_stream<1>(fn_T_19__out_stream, fn_T_19__destinations);
#
# ////////////////
#
#
# // fn_Mm_4
# mm(fn_Mm_4__in_0_stream, fn_Mm_4__in_1_stream, fn_Mm_4__out_stream);
#
# const decltype(fn_Mm_4__out_stream) fn_Mm_4__destinations[1] = { fn_Add_4__in_1_stream };
# copy_stream<1>(fn_Mm_4__out_stream, fn_Mm_4__destinations);
#
# ////////////////
#
#
# // fn_Add_4
# elementwise_add(fn_Add_4__in_0_stream, fn_Add_4__in_1_stream, fn_Add_4__out_stream);
#
# const decltype(fn_Add_4__out_stream) fn_Add_4__destinations[1] = { fn_Mul_3__in_1_stream };
# copy_stream<1>(fn_Add_4__out_stream, fn_Add_4__destinations);
#
# ////////////////
#
#
# // fn_Mul_3
# elementwise_mul(fn_Mul_3__in_0_stream, fn_Mul_3__in_1_stream, fn_Mul_3__out_stream);
#
# const decltype(fn_Mul_3__out_stream) fn_Mul_3__destinations[4] = { fn_Sin_3__in_1_stream, fn_Cos_3__in_1_stream,
# fn_Cos_7__in_1_stream, fn_Cos_11__in_1_stream };
# copy_stream<4>(fn_Mul_3__out_stream, fn_Mul_3__destinations);
#
# ////////////////
#
#
# // fn_Cos_11
# elementwise_cos(fn_Cos_11__in_0_stream, fn_Cos_11__out_stream);
#
# const decltype(fn_Cos_11__out_stream) fn_Cos_11__destinations[1] = { fn_Mul_21__in_1_stream };
# copy_stream<1>(fn_Cos_11__out_stream, fn_Cos_11__destinations);
#
# ////////////////
#
#
# // fn_Cos_3
# elementwise_cos(fn_Cos_3__in_0_stream, fn_Cos_3__out_stream);
#
# const decltype(fn_Cos_3__out_stream) fn_Cos_3__destinations[1] = { fn_Mul_5__in_1_stream };
# copy_stream<1>(fn_Cos_3__out_stream, fn_Cos_3__destinations);
#
# ////////////////
#
#
# // fn_Cos_7
# elementwise_cos(fn_Cos_7__in_0_stream, fn_Cos_7__out_stream);
#
# const decltype(fn_Cos_7__out_stream) fn_Cos_7__destinations[1] = { fn_Mul_13__in_1_stream };
# copy_stream<1>(fn_Cos_7__out_stream, fn_Cos_7__destinations);
#
# ////////////////
#
#
# // fn_Sin_3
# elementwise_sin(fn_Sin_3__in_0_stream, fn_Sin_3__out_stream);
#
# const decltype(fn_Sin_3__out_stream) fn_Sin_3__destinations[1] = { fn_Mm_3__in_1_stream };
# copy_stream<1>(fn_Sin_3__out_stream, fn_Sin_3__destinations);
#
# ////////////////
#
#
# // fn_Mm_3
# mm(fn_Mm_3__in_0_stream, fn_Mm_3__in_1_stream, fn_Mm_3__out_stream);
#
# const decltype(fn_Mm_3__out_stream) fn_Mm_3__destinations[1] = { fn_Add_3__in_1_stream };
# copy_stream<1>(fn_Mm_3__out_stream, fn_Mm_3__destinations);
#
# ////////////////
#
#
# // fn_Add_3
# elementwise_add(fn_Add_3__in_0_stream, fn_Add_3__in_1_stream, fn_Add_3__out_stream);
#
# const decltype(fn_Add_3__out_stream) fn_Add_3__destinations[1] = { fn_Mul_2__in_1_stream };
# copy_stream<1>(fn_Add_3__out_stream, fn_Add_3__destinations);
#
# ////////////////
#
#
# // fn_Mul_2
# elementwise_mul(fn_Mul_2__in_0_stream, fn_Mul_2__in_1_stream, fn_Mul_2__out_stream);
#
# const decltype(fn_Mul_2__out_stream) fn_Mul_2__destinations[4] = { fn_Sin_2__in_1_stream, fn_Cos_2__in_1_stream,
# fn_Cos_6__in_1_stream, fn_Cos_10__in_1_stream };
# copy_stream<4>(fn_Mul_2__out_stream, fn_Mul_2__destinations);
#
# ////////////////
#
#
# // fn_Cos_10
# elementwise_cos(fn_Cos_10__in_0_stream, fn_Cos_10__out_stream);
#
# const decltype(fn_Cos_10__out_stream) fn_Cos_10__destinations[1] = { fn_Mul_23__in_1_stream };
# copy_stream<1>(fn_Cos_10__out_stream, fn_Cos_10__destinations);
#
# ////////////////
#
#
# // fn_Cos_2
# elementwise_cos(fn_Cos_2__in_0_stream, fn_Cos_2__out_stream);
#
# const decltype(fn_Cos_2__out_stream) fn_Cos_2__destinations[1] = { fn_Mul_7__in_1_stream };
# copy_stream<1>(fn_Cos_2__out_stream, fn_Cos_2__destinations);
#
# ////////////////
#
#
# // fn_Cos_6
# elementwise_cos(fn_Cos_6__in_0_stream, fn_Cos_6__out_stream);
#
# const decltype(fn_Cos_6__out_stream) fn_Cos_6__destinations[1] = { fn_Mul_15__in_1_stream };
# copy_stream<1>(fn_Cos_6__out_stream, fn_Cos_6__destinations);
#
# ////////////////
#
#
# // fn_Sin_2
# elementwise_sin(fn_Sin_2__in_0_stream, fn_Sin_2__out_stream);
#
# const decltype(fn_Sin_2__out_stream) fn_Sin_2__destinations[1] = { fn_Mm_2__in_1_stream };
# copy_stream<1>(fn_Sin_2__out_stream, fn_Sin_2__destinations);
#
# ////////////////
#
#
# // fn_Mm_2
# mm(fn_Mm_2__in_0_stream, fn_Mm_2__in_1_stream, fn_Mm_2__out_stream);
#
# const decltype(fn_Mm_2__out_stream) fn_Mm_2__destinations[1] = { fn_Add_2__in_1_stream };
# copy_stream<1>(fn_Mm_2__out_stream, fn_Mm_2__destinations);
#
# ////////////////
#
#
# // fn_Add_2
# elementwise_add(fn_Add_2__in_0_stream, fn_Add_2__in_1_stream, fn_Add_2__out_stream);
#
# const decltype(fn_Add_2__out_stream) fn_Add_2__destinations[1] = { fn_Mul_1__in_1_stream };
# copy_stream<1>(fn_Add_2__out_stream, fn_Add_2__destinations);
#
# ////////////////
#
#
# // fn_Mul_1
# elementwise_mul(fn_Mul_1__in_0_stream, fn_Mul_1__in_1_stream, fn_Mul_1__out_stream);
#
# const decltype(fn_Mul_1__out_stream) fn_Mul_1__destinations[4] = { fn_Sin_1__in_1_stream, fn_Cos_1__in_1_stream,
# fn_Cos_5__in_1_stream, fn_Cos_9__in_1_stream };
# copy_stream<4>(fn_Mul_1__out_stream, fn_Mul_1__destinations);
#
# ////////////////
#
#
# // fn_Cos_1
# elementwise_cos(fn_Cos_1__in_0_stream, fn_Cos_1__out_stream);
#
# const decltype(fn_Cos_1__out_stream) fn_Cos_1__destinations[1] = { fn_Mul_9__in_1_stream };
# copy_stream<1>(fn_Cos_1__out_stream, fn_Cos_1__destinations);
#
# ////////////////
#
#
# // fn_Cos_5
# elementwise_cos(fn_Cos_5__in_0_stream, fn_Cos_5__out_stream);
#
# const decltype(fn_Cos_5__out_stream) fn_Cos_5__destinations[1] = { fn_Mul_17__in_1_stream };
# copy_stream<1>(fn_Cos_5__out_stream, fn_Cos_5__destinations);
#
# ////////////////
#
#
# // fn_Cos_9
# elementwise_cos(fn_Cos_9__in_0_stream, fn_Cos_9__out_stream);
#
# const decltype(fn_Cos_9__out_stream) fn_Cos_9__destinations[1] = { fn_Mul_25__in_1_stream };
# copy_stream<1>(fn_Cos_9__out_stream, fn_Cos_9__destinations);
#
# ////////////////
#
#
# // fn_Sin_1
# elementwise_sin(fn_Sin_1__in_0_stream, fn_Sin_1__out_stream);
#
# const decltype(fn_Sin_1__out_stream) fn_Sin_1__destinations[1] = { fn_Mm_1__in_1_stream };
# copy_stream<1>(fn_Sin_1__out_stream, fn_Sin_1__destinations);
#
# ////////////////
#
#
# // fn_Mm_1
# mm(fn_Mm_1__in_0_stream, fn_Mm_1__in_1_stream, fn_Mm_1__out_stream);
#
# const decltype(fn_Mm_1__out_stream) fn_Mm_1__destinations[1] = { fn_Add_1__in_1_stream };
# copy_stream<1>(fn_Mm_1__out_stream, fn_Mm_1__destinations);
#
# ////////////////
#
#
# // fn_Add_1
# elementwise_add(fn_Add_1__in_0_stream, fn_Add_1__in_1_stream, fn_Add_1__out_stream);
#
# const decltype(fn_Add_1__out_stream) fn_Add_1__destinations[1] = { fn_Mul_0__in_1_stream };
# copy_stream<1>(fn_Add_1__out_stream, fn_Add_1__destinations);
#
# ////////////////
#
#
# // fn_Mul_0
# elementwise_mul(fn_Mul_0__in_0_stream, fn_Mul_0__in_1_stream, fn_Mul_0__out_stream);
#
# const decltype(fn_Mul_0__out_stream) fn_Mul_0__destinations[4] = { fn_Sin_0__in_1_stream, fn_Cos_0__in_1_stream,
# fn_Cos_4__in_1_stream, fn_Cos_8__in_1_stream };
# copy_stream<4>(fn_Mul_0__out_stream, fn_Mul_0__destinations);
#
# ////////////////
#
#
# // fn_Cos_0
# elementwise_cos(fn_Cos_0__in_0_stream, fn_Cos_0__out_stream);
#
# const decltype(fn_Cos_0__out_stream) fn_Cos_0__destinations[1] = { fn_Mul_11__in_1_stream };
# copy_stream<1>(fn_Cos_0__out_stream, fn_Cos_0__destinations);
#
# ////////////////
#
#
# // fn_Cos_4
# elementwise_cos(fn_Cos_4__in_0_stream, fn_Cos_4__out_stream);
#
# const decltype(fn_Cos_4__out_stream) fn_Cos_4__destinations[1] = { fn_Mul_19__in_1_stream };
# copy_stream<1>(fn_Cos_4__out_stream, fn_Cos_4__destinations);
#
# ////////////////
#
#
# // fn_Cos_8
# elementwise_cos(fn_Cos_8__in_0_stream, fn_Cos_8__out_stream);
#
# const decltype(fn_Cos_8__out_stream) fn_Cos_8__destinations[1] = { fn_Mul_27__in_1_stream };
# copy_stream<1>(fn_Cos_8__out_stream, fn_Cos_8__destinations);
#
# ////////////////
#
#
# // fn_Mul_11
# elementwise_mul(fn_Mul_11__in_0_stream, fn_Mul_11__in_1_stream, fn_Mul_11__out_stream);
#
# const decltype(fn_Mul_11__out_stream) fn_Mul_11__destinations[1] = { fn_Mul_10__in_1_stream };
# copy_stream<1>(fn_Mul_11__out_stream, fn_Mul_11__destinations);
#
# ////////////////
#
#
# // fn_Mul_10
# elementwise_mul(fn_Mul_10__in_0_stream, fn_Mul_10__in_1_stream, fn_Mul_10__out_stream);
#
# const decltype(fn_Mul_10__out_stream) fn_Mul_10__destinations[1] = { fn_Mm_8__in_1_stream };
# copy_stream<1>(fn_Mul_10__out_stream, fn_Mul_10__destinations);
#
# ////////////////
#
#
# // fn_Mm_8
# mm(fn_Mm_8__in_0_stream, fn_Mm_8__in_1_stream, fn_Mm_8__out_stream);
#
# const decltype(fn_Mm_8__out_stream) fn_Mm_8__destinations[1] = { fn_Mul_9__in_1_stream };
# copy_stream<1>(fn_Mm_8__out_stream, fn_Mm_8__destinations);
#
# ////////////////
#
#
# // fn_Mul_19
# elementwise_mul(fn_Mul_19__in_0_stream, fn_Mul_19__in_1_stream, fn_Mul_19__out_stream);
#
# const decltype(fn_Mul_19__out_stream) fn_Mul_19__destinations[1] = { fn_Mul_18__in_1_stream };
# copy_stream<1>(fn_Mul_19__out_stream, fn_Mul_19__destinations);
#
# ////////////////
#
#
# // fn_Mul_18
# elementwise_mul(fn_Mul_18__in_0_stream, fn_Mul_18__in_1_stream, fn_Mul_18__out_stream);
#
# const decltype(fn_Mul_18__out_stream) fn_Mul_18__destinations[1] = { fn_Mm_13__in_1_stream };
# copy_stream<1>(fn_Mul_18__out_stream, fn_Mul_18__destinations);
#
# ////////////////
#
#
# // fn_Mm_13
# mm(fn_Mm_13__in_0_stream, fn_Mm_13__in_1_stream, fn_Mm_13__out_stream);
#
# const decltype(fn_Mm_13__out_stream) fn_Mm_13__destinations[1] = { fn_Mul_17__in_1_stream };
# copy_stream<1>(fn_Mm_13__out_stream, fn_Mm_13__destinations);
#
# ////////////////
#
#
# // fn_Mul_17
# elementwise_mul(fn_Mul_17__in_0_stream, fn_Mul_17__in_1_stream, fn_Mul_17__out_stream);
#
# const decltype(fn_Mul_17__out_stream) fn_Mul_17__destinations[1] = { fn_Mul_16__in_1_stream };
# copy_stream<1>(fn_Mul_17__out_stream, fn_Mul_17__destinations);
#
# ////////////////
#
#
# // fn_Mul_16
# elementwise_mul(fn_Mul_16__in_0_stream, fn_Mul_16__in_1_stream, fn_Mul_16__out_stream);
#
# const decltype(fn_Mul_16__out_stream) fn_Mul_16__destinations[1] = { fn_Mm_12__in_1_stream };
# copy_stream<1>(fn_Mul_16__out_stream, fn_Mul_16__destinations);
#
# ////////////////
#
#
# // fn_Mm_12
# mm(fn_Mm_12__in_0_stream, fn_Mm_12__in_1_stream, fn_Mm_12__out_stream);
#
# const decltype(fn_Mm_12__out_stream) fn_Mm_12__destinations[1] = { fn_Mul_15__in_1_stream };
# copy_stream<1>(fn_Mm_12__out_stream, fn_Mm_12__destinations);
#
# ////////////////
#
#
# // fn_Mul_15
# elementwise_mul(fn_Mul_15__in_0_stream, fn_Mul_15__in_1_stream, fn_Mul_15__out_stream);
#
# const decltype(fn_Mul_15__out_stream) fn_Mul_15__destinations[1] = { fn_Mul_14__in_1_stream };
# copy_stream<1>(fn_Mul_15__out_stream, fn_Mul_15__destinations);
#
# ////////////////
#
#
# // fn_Mul_14
# elementwise_mul(fn_Mul_14__in_0_stream, fn_Mul_14__in_1_stream, fn_Mul_14__out_stream);
#
# const decltype(fn_Mul_14__out_stream) fn_Mul_14__destinations[1] = { fn_Mm_11__in_1_stream };
# copy_stream<1>(fn_Mul_14__out_stream, fn_Mul_14__destinations);
#
# ////////////////
#
#
# // fn_Mm_11
# mm(fn_Mm_11__in_0_stream, fn_Mm_11__in_1_stream, fn_Mm_11__out_stream);
#
# const decltype(fn_Mm_11__out_stream) fn_Mm_11__destinations[1] = { fn_Mul_13__in_1_stream };
# copy_stream<1>(fn_Mm_11__out_stream, fn_Mm_11__destinations);
#
# ////////////////
#
#
# // fn_Mul_13
# elementwise_mul(fn_Mul_13__in_0_stream, fn_Mul_13__in_1_stream, fn_Mul_13__out_stream);
#
# const decltype(fn_Mul_13__out_stream) fn_Mul_13__destinations[1] = { fn_Mul_12__in_1_stream };
# copy_stream<1>(fn_Mul_13__out_stream, fn_Mul_13__destinations);
#
# ////////////////
#
#
# // fn_Mul_12
# elementwise_mul(fn_Mul_12__in_0_stream, fn_Mul_12__in_1_stream, fn_Mul_12__out_stream);
#
# const decltype(fn_Mul_12__out_stream) fn_Mul_12__destinations[1] = { fn_Mm_10__in_1_stream };
# copy_stream<1>(fn_Mul_12__out_stream, fn_Mul_12__destinations);
#
# ////////////////
#
#
# // fn_Mm_10
# mm(fn_Mm_10__in_0_stream, fn_Mm_10__in_1_stream, fn_Mm_10__out_stream);
#
# const decltype(fn_Mm_10__out_stream) fn_Mm_10__destinations[2] = { fn_Select_5__in_1_stream,
# fn_Select_6__in_1_stream };
# copy_stream<2>(fn_Mm_10__out_stream, fn_Mm_10__destinations);
#
# ////////////////
#
#
# // fn_Mul_27
# elementwise_mul(fn_Mul_27__in_0_stream, fn_Mul_27__in_1_stream, fn_Mul_27__out_stream);
#
# const decltype(fn_Mul_27__out_stream) fn_Mul_27__destinations[1] = { fn_Mul_26__in_1_stream };
# copy_stream<1>(fn_Mul_27__out_stream, fn_Mul_27__destinations);
#
# ////////////////
#
#
# // fn_Mul_26
# elementwise_mul(fn_Mul_26__in_0_stream, fn_Mul_26__in_1_stream, fn_Mul_26__out_stream);
#
# const decltype(fn_Mul_26__out_stream) fn_Mul_26__destinations[1] = { fn_Mm_18__in_1_stream };
# copy_stream<1>(fn_Mul_26__out_stream, fn_Mul_26__destinations);
#
# ////////////////
#
#
# // fn_Mm_18
# mm(fn_Mm_18__in_0_stream, fn_Mm_18__in_1_stream, fn_Mm_18__out_stream);
#
# const decltype(fn_Mm_18__out_stream) fn_Mm_18__destinations[1] = { fn_Mul_25__in_1_stream };
# copy_stream<1>(fn_Mm_18__out_stream, fn_Mm_18__destinations);
#
# ////////////////
#
#
# // fn_Mul_25
# elementwise_mul(fn_Mul_25__in_0_stream, fn_Mul_25__in_1_stream, fn_Mul_25__out_stream);
#
# const decltype(fn_Mul_25__out_stream) fn_Mul_25__destinations[1] = { fn_Mul_24__in_1_stream };
# copy_stream<1>(fn_Mul_25__out_stream, fn_Mul_25__destinations);
#
# ////////////////
#
#
# // fn_Mul_24
# elementwise_mul(fn_Mul_24__in_0_stream, fn_Mul_24__in_1_stream, fn_Mul_24__out_stream);
#
# const decltype(fn_Mul_24__out_stream) fn_Mul_24__destinations[1] = { fn_Mm_17__in_1_stream };
# copy_stream<1>(fn_Mul_24__out_stream, fn_Mul_24__destinations);
#
# ////////////////
#
#
# // fn_Mm_17
# mm(fn_Mm_17__in_0_stream, fn_Mm_17__in_1_stream, fn_Mm_17__out_stream);
#
# const decltype(fn_Mm_17__out_stream) fn_Mm_17__destinations[1] = { fn_Mul_23__in_1_stream };
# copy_stream<1>(fn_Mm_17__out_stream, fn_Mm_17__destinations);
#
# ////////////////
#
#
# // fn_Mul_23
# elementwise_mul(fn_Mul_23__in_0_stream, fn_Mul_23__in_1_stream, fn_Mul_23__out_stream);
#
# const decltype(fn_Mul_23__out_stream) fn_Mul_23__destinations[1] = { fn_Mul_22__in_1_stream };
# copy_stream<1>(fn_Mul_23__out_stream, fn_Mul_23__destinations);
#
# ////////////////
#
#
# // fn_Mul_22
# elementwise_mul(fn_Mul_22__in_0_stream, fn_Mul_22__in_1_stream, fn_Mul_22__out_stream);
#
# const decltype(fn_Mul_22__out_stream) fn_Mul_22__destinations[1] = { fn_Mm_16__in_1_stream };
# copy_stream<1>(fn_Mul_22__out_stream, fn_Mul_22__destinations);
#
# ////////////////
#
#
# // fn_Mm_16
# mm(fn_Mm_16__in_0_stream, fn_Mm_16__in_1_stream, fn_Mm_16__out_stream);
#
# const decltype(fn_Mm_16__out_stream) fn_Mm_16__destinations[1] = { fn_Mul_21__in_1_stream };
# copy_stream<1>(fn_Mm_16__out_stream, fn_Mm_16__destinations);
#
# ////////////////
#
#
# // fn_Mul_21
# elementwise_mul(fn_Mul_21__in_0_stream, fn_Mul_21__in_1_stream, fn_Mul_21__out_stream);
#
# const decltype(fn_Mul_21__out_stream) fn_Mul_21__destinations[1] = { fn_Mul_20__in_1_stream };
# copy_stream<1>(fn_Mul_21__out_stream, fn_Mul_21__destinations);
#
# ////////////////
#
#
# // fn_Mul_20
# elementwise_mul(fn_Mul_20__in_0_stream, fn_Mul_20__in_1_stream, fn_Mul_20__out_stream);
#
# const decltype(fn_Mul_20__out_stream) fn_Mul_20__destinations[1] = { fn_Mm_15__in_1_stream };
# copy_stream<1>(fn_Mul_20__out_stream, fn_Mul_20__destinations);
#
# ////////////////
#
#
# // fn_Mm_15
# mm(fn_Mm_15__in_0_stream, fn_Mm_15__in_1_stream, fn_Mm_15__out_stream);
#
# const decltype(fn_Mm_15__out_stream) fn_Mm_15__destinations[2] = { fn_Select_7__in_1_stream,
# fn_Select_8__in_1_stream };
# copy_stream<2>(fn_Mm_15__out_stream, fn_Mm_15__destinations);
#
# ////////////////
#
#
# // fn_Mul_9
# elementwise_mul(fn_Mul_9__in_0_stream, fn_Mul_9__in_1_stream, fn_Mul_9__out_stream);
#
# const decltype(fn_Mul_9__out_stream) fn_Mul_9__destinations[1] = { fn_Mul_8__in_1_stream };
# copy_stream<1>(fn_Mul_9__out_stream, fn_Mul_9__destinations);
#
# ////////////////
#
#
# // fn_Mul_8
# elementwise_mul(fn_Mul_8__in_0_stream, fn_Mul_8__in_1_stream, fn_Mul_8__out_stream);
#
# const decltype(fn_Mul_8__out_stream) fn_Mul_8__destinations[1] = { fn_Mm_7__in_1_stream };
# copy_stream<1>(fn_Mul_8__out_stream, fn_Mul_8__destinations);
#
# ////////////////
#
#
# // fn_Mm_7
# mm(fn_Mm_7__in_0_stream, fn_Mm_7__in_1_stream, fn_Mm_7__out_stream);
#
# const decltype(fn_Mm_7__out_stream) fn_Mm_7__destinations[1] = { fn_Mul_7__in_1_stream };
# copy_stream<1>(fn_Mm_7__out_stream, fn_Mm_7__destinations);
#
# ////////////////
#
#
# // fn_Mul_7
# elementwise_mul(fn_Mul_7__in_0_stream, fn_Mul_7__in_1_stream, fn_Mul_7__out_stream);
#
# const decltype(fn_Mul_7__out_stream) fn_Mul_7__destinations[1] = { fn_Mul_6__in_1_stream };
# copy_stream<1>(fn_Mul_7__out_stream, fn_Mul_7__destinations);
#
# ////////////////
#
#
# // fn_Mul_6
# elementwise_mul(fn_Mul_6__in_0_stream, fn_Mul_6__in_1_stream, fn_Mul_6__out_stream);
#
# const decltype(fn_Mul_6__out_stream) fn_Mul_6__destinations[1] = { fn_Mm_6__in_1_stream };
# copy_stream<1>(fn_Mul_6__out_stream, fn_Mul_6__destinations);
#
# ////////////////
#
#
# // fn_Mm_6
# mm(fn_Mm_6__in_0_stream, fn_Mm_6__in_1_stream, fn_Mm_6__out_stream);
#
# const decltype(fn_Mm_6__out_stream) fn_Mm_6__destinations[1] = { fn_Mul_5__in_1_stream };
# copy_stream<1>(fn_Mm_6__out_stream, fn_Mm_6__destinations);
#
# ////////////////
#
#
# // fn_Mul_5
# elementwise_mul(fn_Mul_5__in_0_stream, fn_Mul_5__in_1_stream, fn_Mul_5__out_stream);
#
# const decltype(fn_Mul_5__out_stream) fn_Mul_5__destinations[1] = { fn_Mul_4__in_1_stream };
# copy_stream<1>(fn_Mul_5__out_stream, fn_Mul_5__destinations);
#
# ////////////////
#
#
# // fn_Mul_4
# elementwise_mul(fn_Mul_4__in_0_stream, fn_Mul_4__in_1_stream, fn_Mul_4__out_stream);
#
# const decltype(fn_Mul_4__out_stream) fn_Mul_4__destinations[1] = { fn_Mm_5__in_1_stream };
# copy_stream<1>(fn_Mul_4__out_stream, fn_Mul_4__destinations);
#
# ////////////////
#
#
# // fn_Mm_5
# mm(fn_Mm_5__in_0_stream, fn_Mm_5__in_1_stream, fn_Mm_5__out_stream);
#
# const decltype(fn_Mm_5__out_stream) fn_Mm_5__destinations[2] = { fn_Select_3__in_1_stream, fn_Select_4__in_1_stream
# };
# copy_stream<2>(fn_Mm_5__out_stream, fn_Mm_5__destinations);
#
# ////////////////
#
#
# // fn_Select_3
# select<1, 0>(fn_Select_3__in_0_stream, fn_Select_3__out_stream);
#
# const decltype(fn_Select_3__out_stream) fn_Select_3__destinations[1] = { output_3_stream };
# copy_stream<1>(fn_Select_3__out_stream, fn_Select_3__destinations);
#
# ////////////////
#
#
# // fn_Select_4
# select<1, 1>(fn_Select_4__in_0_stream, fn_Select_4__out_stream);
#
# const decltype(fn_Select_4__out_stream) fn_Select_4__destinations[1] = { output_4_stream };
# copy_stream<1>(fn_Select_4__out_stream, fn_Select_4__destinations);
#
# ////////////////
#
#
# // fn_Select_5
# select<1, 0>(fn_Select_5__in_0_stream, fn_Select_5__out_stream);
#
# const decltype(fn_Select_5__out_stream) fn_Select_5__destinations[1] = { output_5_stream };
# copy_stream<1>(fn_Select_5__out_stream, fn_Select_5__destinations);
#
# ////////////////
#
#
# // fn_Select_6
# select<1, 1>(fn_Select_6__in_0_stream, fn_Select_6__out_stream);
#
# const decltype(fn_Select_6__out_stream) fn_Select_6__destinations[1] = { output_6_stream };
# copy_stream<1>(fn_Select_6__out_stream, fn_Select_6__destinations);
#
# ////////////////
#
#
# // fn_Select_7
# select<1, 0>(fn_Select_7__in_0_stream, fn_Select_7__out_stream);
#
# const decltype(fn_Select_7__out_stream) fn_Select_7__destinations[1] = { output_7_stream };
# copy_stream<1>(fn_Select_7__out_stream, fn_Select_7__destinations);
#
# ////////////////
#
#
# // fn_Select_8
# select<1, 1>(fn_Select_8__in_0_stream, fn_Select_8__out_stream);
#
# const decltype(fn_Select_8__out_stream) fn_Select_8__destinations[1] = { output_8_stream };
# copy_stream<1>(fn_Select_8__out_stream, fn_Select_8__destinations);
#
# ////////////////
#
#
# // fn_Sin_0
# elementwise_sin(fn_Sin_0__in_0_stream, fn_Sin_0__out_stream);
#
# const decltype(fn_Sin_0__out_stream) fn_Sin_0__destinations[1] = { fn_Mm_0__in_1_stream };
# copy_stream<1>(fn_Sin_0__out_stream, fn_Sin_0__destinations);
#
# ////////////////
#
#
# // fn_Mm_0
# mm(fn_Mm_0__in_0_stream, fn_Mm_0__in_1_stream, fn_Mm_0__out_stream);
#
# const decltype(fn_Mm_0__out_stream) fn_Mm_0__destinations[1] = { fn_Add_0__in_1_stream };
# copy_stream<1>(fn_Mm_0__out_stream, fn_Mm_0__destinations);
#
# ////////////////
#
#
# // fn_Add_0
# elementwise_add(fn_Add_0__in_0_stream, fn_Add_0__in_1_stream, fn_Add_0__out_stream);
#
# const decltype(fn_Add_0__out_stream) fn_Add_0__destinations[3] = { fn_Select_0__in_1_stream,
# fn_Select_1__in_1_stream, fn_Select_2__in_1_stream };
# copy_stream<3>(fn_Add_0__out_stream, fn_Add_0__destinations);
#
# ////////////////
#
#
# // fn_Select_0
# select<1, 0>(fn_Select_0__in_0_stream, fn_Select_0__out_stream);
#
# const decltype(fn_Select_0__out_stream) fn_Select_0__destinations[1] = { output_0_stream };
# copy_stream<1>(fn_Select_0__out_stream, fn_Select_0__destinations);
#
# ////////////////
#
#
# // fn_Select_1
# select<1, 1>(fn_Select_1__in_0_stream, fn_Select_1__out_stream);
#
# const decltype(fn_Select_1__out_stream) fn_Select_1__destinations[1] = { output_1_stream };
# copy_stream<1>(fn_Select_1__out_stream, fn_Select_1__destinations);
#
# ////////////////
#
#
# // fn_Select_2
# select<1, 2>(fn_Select_2__in_0_stream, fn_Select_2__out_stream);
#
# const decltype(fn_Select_2__out_stream) fn_Select_2__destinations[1] = { output_2_stream };
# copy_stream<1>(fn_Select_2__out_stream, fn_Select_2__destinations);
#
# ////////////////
#
#
# array_stream_to_array_1d<F_TYPE, 4096>(output_0_stream, output_0);
# array_stream_to_array_1d<F_TYPE, 4096>(output_1_stream, output_1);
# array_stream_to_array_1d<F_TYPE, 4096>(output_2_stream, output_2);
# array_stream_to_array_1d<F_TYPE, 4096>(output_3_stream, output_3);
# array_stream_to_array_1d<F_TYPE, 4096>(output_4_stream, output_4);
# array_stream_to_array_1d<F_TYPE, 4096>(output_5_stream, output_5);
# array_stream_to_array_1d<F_TYPE, 4096>(output_6_stream, output_6);
# array_stream_to_array_1d<F_TYPE, 4096>(output_7_stream, output_7);
# array_stream_to_array_1d<F_TYPE, 4096>(output_8_stream, output_8);
#
#
# }
#
# void copy_inputs_top(){
# copy_1d<F_TYPE, 256>(input_net_0_0_bias_top, input_net_0_0_bias);
# copy_2d<F_TYPE, 256, 2>(input_net_0_0_weight_top, input_net_0_0_weight);
# copy_1d<F_TYPE, 256>(input_net_1_0_bias_top, input_net_1_0_bias);
# copy_2d<F_TYPE, 256, 256>(input_net_1_0_weight_top, input_net_1_0_weight);
# copy_1d<F_TYPE, 256>(input_net_2_0_bias_top, input_net_2_0_bias);
# copy_2d<F_TYPE, 256, 256>(input_net_2_0_weight_top, input_net_2_0_weight);
# copy_1d<F_TYPE, 256>(input_net_3_0_bias_top, input_net_3_0_bias);
# copy_2d<F_TYPE, 256, 256>(input_net_3_0_weight_top, input_net_3_0_weight);
# copy_1d<F_TYPE, 3>(input_net_4_0_bias_top, input_net_4_0_bias);
# copy_2d<F_TYPE, 3, 256>(input_net_4_0_weight_top, input_net_4_0_weight);
# copy_2d<F_TYPE, 4096, 2>(input_x_top, input_x);
# }
#
# void copy_outputs_top(){
# copy_1d<F_TYPE, 4096>(output_0, output_0_top);
# copy_1d<F_TYPE, 4096>(output_1, output_1_top);
# copy_1d<F_TYPE, 4096>(output_2, output_2_top);
# copy_1d<F_TYPE, 4096>(output_3, output_3_top);
# copy_1d<F_TYPE, 4096>(output_4, output_4_top);
# copy_1d<F_TYPE, 4096>(output_5, output_5_top);
# copy_1d<F_TYPE, 4096>(output_6, output_6_top);
# copy_1d<F_TYPE, 4096>(output_7, output_7_top);
# copy_1d<F_TYPE, 4096>(output_8, output_8_top);
# }
# void model_top(
# F_TYPE input_net_0_0_bias_top[256],
#     F_TYPE input_net_0_0_weight_top[256][2],
#     F_TYPE input_net_1_0_bias_top[256],
#     F_TYPE input_net_1_0_weight_top[256][256],
#     F_TYPE input_net_2_0_bias_top[256],
#     F_TYPE input_net_2_0_weight_top[256][256],
#     F_TYPE input_net_3_0_bias_top[256],
#     F_TYPE input_net_3_0_weight_top[256][256],
#     F_TYPE input_net_4_0_bias_top[3],
#     F_TYPE input_net_4_0_weight_top[3][256],
#     F_TYPE input_x_top[4096][2],
#     F_TYPE output_0_top[4096],
#     F_TYPE output_1_top[4096],
#     F_TYPE output_2_top[4096],
#     F_TYPE output_3_top[4096],
#     F_TYPE output_4_top[4096],
#     F_TYPE output_5_top[4096],
#     F_TYPE output_6_top[4096],
#     F_TYPE output_7_top[4096],
#     F_TYPE output_8_top[4096]){
#
# copy_inputs_top();
#
# main_dataflow_region();
#
# copy_outputs_top();
#
# }
